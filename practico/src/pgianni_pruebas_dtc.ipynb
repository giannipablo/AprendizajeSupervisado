# %%
# Import the required packages
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score

from sklearn.preprocessing import StandardScaler

# %%
def transform_data(train_data_fname, test_data_fname):
    df_train = pd.read_csv(train_data_fname)
    df_train['is_train_set'] = 1
    df_test = pd.read_csv(test_data_fname)
    df_test['is_train_set'] = 0

    # we  get the TripType for the train set. To do that, we group by VisitNumber and
    # then we get the max (or min or avg)
    y = df_train.groupby(["VisitNumber", "Weekday"], as_index=False).max().TripType

    # we remove the TripType now, and concat training and testing data
    # the concat is done so that we have the same columns for both datasets
    # after one-hot encoding
    df_train = df_train.drop("TripType", axis=1)
    df = pd.concat([df_train, df_test])
    
    # the next three operations are the ones we have just presented in the previous lines
    
    # drop the columns we won't use (it may be good to use them somehow)
    df = df.drop(["Upc", "FinelineNumber"], axis=1)

    # one-hot encoding for the DepartmentDescription
    df = pd.get_dummies(df, columns=["DepartmentDescription"], dummy_na=True)

    # now we add the groupby values
    df = df.groupby(["VisitNumber", "Weekday"], as_index=False).sum()
    
    # finally, we do one-hot encoding for the Weekday
    df = pd.get_dummies(df, columns=["Weekday"], dummy_na=True)

    # get train and test back
    df_train = df[df.is_train_set != 0]
    df_test = df[df.is_train_set == 0]
    
    X = df_train.drop(["is_train_set"], axis=1)
    yy = None
    XX = df_test.drop(["is_train_set"], axis=1)

    return X, y, XX, yy

# %%
X, y, XX, yy = transform_data("../data/train.csv", "../data/test.csv")


X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.3, random_state=42)

# Normalización
SS = StandardScaler()
SS.fit(X_train)
X_train = SS.transform(X_train)
X_valid = SS.transform(X_valid)

# %%
dtc_model = DecisionTreeClassifier(random_state=42)

param_grid_dtc = [
#   {'splitter': ['best'],
#           'criterion': ['gini', 'entropy'],
#           'max_depth': list(np.arange(25,125,25))+[None],
#           'min_samples_leaf': np.arange(1,10,2),
#           'min_samples_split': np.arange(2,10,2),
#           'max_features': [None, 'sqrt', 'log2']
#           }
    {'splitter': ['best'],
        'criterion': ['gini'],
        'max_depth': [None],
        'min_samples_leaf': np.arange(1,10,2),
        'min_samples_split': np.arange(100,200,25),
        'max_features': [None]
    }
# ,
#   {'splitter': ['random'],
#           'criterion': ['gini', 'entropy'],
#           'max_depth': list(np.arange(25,125,25))+[None],
#           'min_samples_leaf': np.arange(1,10,2),
#           'min_samples_split': np.arange(2,10,2)
#           }
]

gscv_dtc = GridSearchCV(dtc_model, param_grid_dtc, cv=3, scoring=['accuracy'], refit=False, n_jobs=-1, verbose=4) #n_jobs es paralelizar
gscv_dtc.fit(X_train, y_train);
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:   20.1s finished

# %%
gscv_dtc_res = pd.DataFrame(gscv_dtc.cv_results_)
gscv_dtc_res.sort_values(by='rank_test_accuracy') #.to_csv('./prueba3.csv')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 8        1.080115      0.009358         0.016124        0.001031
# 12       1.119245      0.010971         0.016809        0.000481
# 9        1.095671      0.021999         0.018432        0.002316
# 4        1.175571      0.007287         0.017599        0.001862
# 5        1.220766      0.049982         0.017202        0.000605
# 13       1.120036      0.018395         0.016796        0.000891
# 16       1.086185      0.007787         0.017177        0.001409
# 1        1.262296      0.030976         0.020691        0.002095
# 0        1.253388      0.022667         0.020715        0.002663
# 10       1.101925      0.029035         0.018240        0.001564
# 6        1.206589      0.018158         0.017409        0.001112
# 2        1.249566      0.029530         0.022090        0.006130
# 17       1.060476      0.024993         0.015308        0.000238
# 14       1.107851      0.017797         0.016403        0.000133
# 3        1.183350      0.037558         0.017511        0.001408
# 7        1.162139      0.026995         0.016424        0.000698
# 11       1.126553      0.009794         0.019621        0.004330
# 15       1.085030      0.024351         0.017437        0.001908
# 18       1.062727      0.019866         0.015848        0.000931
# 19       1.063591      0.011215         0.015751        0.000049
#
#    param_criterion param_max_depth param_max_features param_min_samples_leaf  \
# 8             gini            None               None                      5
# 12            gini            None               None                      7
# 9             gini            None               None                      5
# 4             gini            None               None                      3
# 5             gini            None               None                      3
# 13            gini            None               None                      7
# 16            gini            None               None                      9
# 1             gini            None               None                      1
# 0             gini            None               None                      1
# 10            gini            None               None                      5
# 6             gini            None               None                      3
# 2             gini            None               None                      1
# 17            gini            None               None                      9
# 14            gini            None               None                      7
# 3             gini            None               None                      1
# 7             gini            None               None                      3
# 11            gini            None               None                      5
# 15            gini            None               None                      7
# 18            gini            None               None                      9
# 19            gini            None               None                      9
#
#    param_min_samples_split param_splitter  \
# 8                      100           best
# 12                     100           best
# 9                      125           best
# 4                      100           best
# 5                      125           best
# 13                     125           best
# 16                     100           best
# 1                      125           best
# 0                      100           best
# 10                     150           best
# 6                      150           best
# 2                      150           best
# 17                     125           best
# 14                     150           best
# 3                      175           best
# 7                      175           best
# 11                     175           best
# 15                     175           best
# 18                     150           best
# 19                     175           best
#
#                                                params  split0_test_accuracy  \
# 8   {'criterion': 'gini', 'max_depth': None, 'max_...              0.626854
# 12  {'criterion': 'gini', 'max_depth': None, 'max_...              0.627749
# 9   {'criterion': 'gini', 'max_depth': None, 'max_...              0.627558
# 4   {'criterion': 'gini', 'max_depth': None, 'max_...              0.627110
# 5   {'criterion': 'gini', 'max_depth': None, 'max_...              0.627238
# 13  {'criterion': 'gini', 'max_depth': None, 'max_...              0.626982
# 16  {'criterion': 'gini', 'max_depth': None, 'max_...              0.625320
# 1   {'criterion': 'gini', 'max_depth': None, 'max_...              0.627366
# 0   {'criterion': 'gini', 'max_depth': None, 'max_...              0.626918
# 10  {'criterion': 'gini', 'max_depth': None, 'max_...              0.624808
# 6   {'criterion': 'gini', 'max_depth': None, 'max_...              0.624552
# 2   {'criterion': 'gini', 'max_depth': None, 'max_...              0.625320
# 17  {'criterion': 'gini', 'max_depth': None, 'max_...              0.625512
# 14  {'criterion': 'gini', 'max_depth': None, 'max_...              0.624425
# 3   {'criterion': 'gini', 'max_depth': None, 'max_...              0.624872
# 7   {'criterion': 'gini', 'max_depth': None, 'max_...              0.624361
# 11  {'criterion': 'gini', 'max_depth': None, 'max_...              0.623849
# 15  {'criterion': 'gini', 'max_depth': None, 'max_...              0.623849
# 18  {'criterion': 'gini', 'max_depth': None, 'max_...              0.622570
# 19  {'criterion': 'gini', 'max_depth': None, 'max_...              0.622315
#
#     split1_test_accuracy  split2_test_accuracy  mean_test_accuracy  \
# 8               0.629540              0.634719            0.630371
# 12              0.629476              0.633760            0.630328
# 9               0.628772              0.633312            0.629881
# 4               0.629795              0.632225            0.629710
# 5               0.630179              0.630946            0.629454
# 13              0.628772              0.632417            0.629390
# 16              0.630179              0.631202            0.628900
# 1               0.628708              0.630115            0.628730
# 0               0.627813              0.630627            0.628453
# 10              0.628900              0.631202            0.628303
# 6               0.630115              0.629668            0.628112
# 2               0.629604              0.628772            0.627899
# 17              0.628325              0.629731            0.627856
# 14              0.628069              0.630243            0.627579
# 3               0.627749              0.628325            0.626982
# 7               0.627941              0.628581            0.626961
# 11              0.626854              0.628581            0.626428
# 15              0.626535              0.627430            0.625938
# 18              0.627110              0.626662            0.625448
# 19              0.626854              0.625320            0.624829
#
#     std_test_accuracy  rank_test_accuracy
# 8            0.003264                   1
# 12           0.002527                   2
# 9            0.002477                   3
# 4            0.002089                   4
# 5            0.001598                   5
# 13           0.002261                   6
# 16           0.002566                   7
# 1            0.001123                   8
# 0            0.001580                   9
# 10           0.002644                  10
# 6            0.002523                  11
# 2            0.001855                  12
# 17           0.001754                  13
# 14           0.002401                  14
# 3            0.001510                  15
# 7            0.001857                  16
# 11           0.001955                  17
# 15           0.001521                  18
# 18           0.002043                  19
# 19           0.001885                  20

# %%
best = gscv_dtc_res[gscv_dtc_res.rank_test_accuracy==1]
best.to_csv('./pg_submission_best_config.csv')

# %%
dtc_model = DecisionTreeClassifier(**best.params.values[0], random_state=42)
dtc_model.fit(X_train, y_train)

y_pred_train = dtc_model.predict(X_train)
y_pred_valid = dtc_model.predict(X_valid)

accuracy_score(y_train, y_pred_train),accuracy_score(y_valid, y_pred_valid)
# Out:
# (0.6757033248081842, 0.6344422895221046)

# %%
XXn = SS.transform(XX)
y2send = dtc_model.predict(XXn)

# %%
submission = pd.DataFrame(list(zip(XX.VisitNumber, y2send)), columns=["VisitNumber", "TripType"])
submission.to_csv("./pg_submission_dtc.csv", header=True, index=False)
